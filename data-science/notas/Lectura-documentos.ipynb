# %% [markdown]
# <a href="https://colab.research.google.com/github/BjorkMagno/Portafolio/blob/main/data-science/notas/Lectura-documentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lectura de archivos**
#
# Diferentes extensiones: csv,xlsx,json...

# %%
import pandas as pd

# %% [markdown]
# ## **Archivos CSV**

# %% [markdown]
# ### Importando archivos CSV
#
# Mediante la **lectura de datos** con la función
#
# ```
# .read()
# ```
# Documentación: [pandas.read( )](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)

# %%
# Almacenaciento de la lectura de CSV, con separación de comun
datos_normal = pd.read_csv('/content/superstore_data.csv')
datos_normal.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
# ALmacenamiento de lectura de un archivo cvs con ; de semparación.
datos_separador = pd.read_csv('/content/superstore_data_punto_coma.csv', sep=';')
datos_separador.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
# Lectura de las primeras filas.
datos_nrow = pd.read_csv('/content/superstore_data.csv', nrows=6)
datos_nrow
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
# 5   7348        1958         PhD         Single   71691        0         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
# ...

# %%
# Lectura de columnas especificas.
datos_usecols = pd.read_csv('/content/superstore_data.csv', usecols=['Id','Year_Birth','Income'])
datos_usecols
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
# Lectura de columnas por número.
datos_usecols_index = pd.read_csv('/content/superstore_data.csv', usecols=[0,1,4])
datos_usecols_index
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ### *Importación de csv online.*
#
# Antes de empezar verfique que el archivo CSV esté separado por una coma o punto y coma. La codificación del archivo es ISO-8859-1.
#
# Note que las primeras tres líneas del archivo se pueden ignorar, ya que el encabezado sólo comienza en la cuarta línea; y las últimas 9 líneas también se pueden ignorar, ya que son sólo información sobre dónde se tomaron los datos. Para eliminar las últimas líneas es necesario agregar el parámetro `engine='python'`.

# %%
# Almacenamiento de dirección.
url_csv ='/content/datos_sus.csv'

# %% [markdown]
# Luego podemos leer la url con la función read_csv y agregar los parámetros:
#
# - `encoding='ISO-8859-1'`: tipo de codificación de caracteres del archivo. En este caso, es la codificación ISO-8859-1 la que es común en los archivos en idioma portugués.
# - `sep=';'`: separador de los valores del archivo. En este caso, es el punto y coma (;).
# - `skiprows=3`: indica que las primeras tres líneas del archivo deben ignorarse ya que no contienen datos relevantes.
# - `skipfooter=9`: Indica que las últimas nueve líneas del archivo deben ignorarse ya que no contienen datos relevantes.
# -` engine='python'`: el motor utilizado para leer el archivo es Python. Esto es necesario cuando se utiliza el parámetro skipfooter, ya que el motor predeterminado no admite esta opción.

# %%
# ALmacenamienrtos de datos.
datos_url = pd.read_csv(url_csv, encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter = 9, engine='python')
datos_url.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0             Rondônia   1388528,39   2931283,42   1541682,52   1525314,96
# 1                 Acre    902416,00   1497206,26   1794028,48   1730469,42
# 2             Amazonas   4735529,42   7118990,57   8196635,49   8259378,42
# 3              Roraima    657889,53    777939,31    718688,03    839994,39
# 4                 Pará  18864744,11  19553758,20  21937342,70  20842829,69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953,84   1406150,68   3065279,01   3231494,61   3117178,63  ...
# 1   1819443,92   1828496,00   2511754,59   2089107,14   2275708,53  ...
# 2   7831399,90   8477273,62   9368858,72   9352532,70   9363099,35  ...
# 3    862347,96    832440,66    996693,09    894271,18    910424,17  ...
# 4  23249952,88  23240687,56  24002223,56  23341218,03  25172261,32  ...
#
#       2020/Jul     2020/Ago     2020/Set     2020/Out     2020/Nov  \
# ...

# %% [markdown]
# ### Exportación de un DataFrame a CSV
#
# Mediante la **exportacion de datos** con la función
#
# ```
# .to_csv()
# ```
#
# Documentación: [pandas.to_csv( )](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html#pandas.DataFrame.to_csv)

# %%
# Importación con index.
datos_normal.to_csv('datos_normal.csv')

# %%
# Importación con index sin index anterior.
datos_normal.to_csv('datos_normal_sin_index.csv', index=False)

# %% [markdown]
# ## **Archivos EXCEL**

# %% [markdown]
# ### Importación de arcivos EXCEL
#
# Mediante la **lectura de datos** con la función
#
# ```
# .read_excel()
# ```
# Documentación: [read_excel()](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html#pandas.read_excel)

# %%
# Declaración de la variable archivo.
archivo = '/content/emisiones_CO2.xlsx'

# %%
# Almacenamiento y lectura del archivo.
datos_xlsx = pd.read_excel(archivo)
datos_xlsx.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    0.0     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    0.0     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    0.0     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    0.0     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    0.0     NaN     NaN  NaN      NaN
#
#    Quema  Otros  Per Capita
# 0    NaN    NaN         NaN
# 1    NaN    NaN         NaN
# 2    NaN    NaN         NaN
# 3    NaN    NaN         NaN
# 4    NaN    NaN         NaN

# %%
# Lista con todas las hojas del EXCEL
pd.ExcelFile(archivo).sheet_names
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %% [markdown]
# Para ver los primeros n datos.
# ```
# head(n)
# ```
# Para ver los ultimos n datos.
# ```
# tail(n)
# ```
# Para ver n datos aleatorios.
# ```
# sample(n)
# ```
# En caso de no poner nada se muestran 5.

# %%
# Almacenamiento de una hoja del excel por defecto es la primera.
datos_emisiones_percapita = pd.read_excel(archivo, sheet_name='fuentes')
datos_emisiones_percapita.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    NaN     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    NaN     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    NaN     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    NaN     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    NaN     NaN     NaN  NaN      NaN
#
#    Quema  Otros
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN

# %%
# Almacenamiento de la lectura de datos de A:D
datos_intervalo = pd.read_excel(archivo, sheet_name='emisiones_C02' , usecols='A:D')
datos_intervalo.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750    0.0
# 1  Afganistán                AFG  1751    0.0
# 2  Afganistán                AFG  1752    0.0
# 3  Afganistán                AFG  1753    0.0
# 4  Afganistán                AFG  1754    0.0

# %%
# Almacenamiento de la lectura de datos de A:D y 10 filas
datos_intervalo_nrows = pd.read_excel(archivo, sheet_name='emisiones_C02' , usecols='A:D', nrows=10)
datos_intervalo_nrows
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %% [markdown]
# ### Importacion de Google sheets
#
# [https://docs.google.com/spreadsheets/d/1HjqlNjLsCZVnRlGhYdLCbZnorIhIl84a_0cMJAXWZDA/edit?usp=sharing](https://docs.google.com/spreadsheets/d/1HjqlNjLsCZVnRlGhYdLCbZnorIhIl84a_0cMJAXWZDA/edit?usp=sharing)

# %%
# Almacenamiento de url dinamico de google sheets.
sheet_id = '1HjqlNjLsCZVnRlGhYdLCbZnorIhIl84a_0cMJAXWZDA'
sheet_name = 'emisiones_C02'
url_xlsx = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
# Almacenamiento de xlsx a DataFrame
datos_online = pd.read_csv(url_xlsx)
datos_online.head()
# Out:
#          País ISO 3166-1 alpha-3   Año Total Carbón Aceite  Gas Cemento Quema  \
# 0  Afganistán                AFG  1750     0    NaN    NaN  NaN     NaN   NaN
# 1  Afganistán                AFG  1751     0    NaN    NaN  NaN     NaN   NaN
# 2  Afganistán                AFG  1752     0    NaN    NaN  NaN     NaN   NaN
# 3  Afganistán                AFG  1753     0    NaN    NaN  NaN     NaN   NaN
# 4  Afganistán                AFG  1754     0    NaN    NaN  NaN     NaN   NaN
#
#   Otros Per Capita
# 0   NaN        NaN
# 1   NaN        NaN
# 2   NaN        NaN
# 3   NaN        NaN
# 4   NaN        NaN

# %% [markdown]
# ### Importacion Ejercicio.
#
# Tenemos un [link de Google Sheets](https://cdn3.gnarususercontent.com.br/1980-pandas-e-s/emisiones_carbono_mundo.xlsx) que contiene datos importantes sobre las emisiones de dióxido de carbono en todo el mundo. El conjunto de datos se obtuvo de [Kaggle](https://www.kaggle.com/datasets/koustavghosh149/co2-emission-around-the-world) y consta de las emisiones de CO2 per cápita de todos los países del mundo entre 1990 y 2019.
#
# En este desafío, tu función es leer este link de Google Sheets y luego guardar el DataFrame obtenido en formato CSV.

# %% [markdown]
# ### Exportación de un DataFrame a EXCEL.
#
# Mediante la **exportación de datos** con la función
#
# ```
# .to_excel()
# ```
# Documentación: [pandas.to_excel( )](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_excel.html#pandas.DataFrame.to_excel)

# %%
# Exportación del documento sin index.
datos_intervalo.to_excel("datos_intervalo.xlsx", index=False)

# %% [markdown]
# ## Archivos JSON

# %% [markdown]
# ### Importación de JSON
# En [JSON Viewer](https://jsonviewer.stack.hu/) podemos ver el contenido de json de forma virtual.
#
# Mediante la **lectura de datos** con la función
#
# ```
# .read_json()
# ```
# Documentación: [read_json()](https://pandas.pydata.org/docs/reference/api/pandas.read_json.html#pandas.read_json)

# %%
# Almacenamiento y lectura de un documento JSON sin información anidada.
datos_json = pd.read_json('/content/pacientes.json')
datos_json.head()
# Out:
#    ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0            0                 No  16.60      Sí              No  No
# 1            1                 No  20.34      No              No  Sí
# 2            2                 No  26.58      Sí              No  No
# 3            3                 No  24.21      No              No  No
# 4            4                 No  23.71      No              No  No
#
#    Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# 0             3            30                 No       Femenino      55-59
# 1             0             0                 No       Femenino     80 ó +
# 2            20            30                 No      Masculino      65-69
# 3             0             0                 No       Femenino      75-79
# 4            28             0                 Sí       Femenino      40-44
#
#      Raza Diabetes Actividad_fisica Salud_general  Horas_sueño Asma  \
# ...

# %% [markdown]
# Para **visualizar** información de JSON y saber como es el archivo anidados podemos ver en [JSON CRACK](https://jsoncrack.com/editor)

# %%
# Almacenamiento y lectura de un documento json con información anidada.
datos_json_anidado = pd.read_json('/content/pacientes_2.json')
datos_json_anidado.head()
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %%
# Solción en data frame (solo para data frame)
datos_json_normalizado =pd.json_normalize(datos_json_anidado['Pacientes'])
datos_json_normalizado.head()
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %%
#Importando la biblioteca Pandas
import pandas as pd

#Importando el módulo JSON
import json

#Leyendo el archivo json usando el módulo Python JSON
with open('pacientes_2.json','r') as f:
    datos = json.loads(f.read())

#Normalizando los datos con los parámetros record_path y meta
pd.json_normalize(datos, record_path='Pacientes', meta=['Investigación', 'Año'])
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud  \
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]
#
#                                  Investigación   Año
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# ...

# %% [markdown]
# ### Exportación de un DataFrame a JSON
#
# Mediante la **exportación de datos** con la función
#
# ```
# .to_json()
# ```
# Documentación: [pandas.to_json( )](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_json.html#pandas.DataFrame.to_json)

# %%
# Exportación de datos en json, no necesario decir idex false.
datos_json.to_json('pacientes_json.json')

# %% [markdown]
# ### Importación desde url

# %%
# Importacion paqueria importante
import requests
import json
# Importación de json a text
datos_frutas = requests.get('https://fruityvice.com/api/fruit/all')
# Descarga
resultado = json.loads(datos_frutas.text)
# Almacenamiento usual, normalizando.
resultado = pd.json_normalize(resultado)
resultado.head()
# Out:
#          name  id      family         order      genus  nutritions.calories  \
# 0   Persimmon  52   Ebenaceae       Rosales  Diospyros                   81
# 1  Strawberry   3    Rosaceae       Rosales   Fragaria                   29
# 2      Banana   1    Musaceae  Zingiberales       Musa                   96
# 3      Tomato   5  Solanaceae     Solanales    Solanum                   74
# 4        Pear   4    Rosaceae       Rosales      Pyrus                   57
#
#    nutritions.fat  nutritions.sugar  nutritions.carbohydrates  \
# 0             0.0              18.0                      18.0
# 1             0.4               5.4                       5.5
# 2             0.2              17.2                      22.0
# 3             0.2               2.6                       3.9
# 4             0.1              10.0                      15.0
#
#    nutritions.protein
# 0                 0.0
# 1                 0.8
# 2                 1.0
# 3                 0.9
# ...

# %% [markdown]
# ## Archivos HTML e XLM

# %% [markdown]
# ### Importación de HTML
#
# Mediante la **lectura de datos** con la función
#
# ```
# .read_html()
# ```
# Documentación: [read_html( )](https://pandas.pydata.org/docs/reference/api/pandas.read_html.html#pandas.read_html)

# %%
# Almacenamiento y lectura de html.
datos_html = pd.read_html('/content/peliculas_wikipedia.html')
datos_html
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                              Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
# ...

# %% [markdown]
# Aqui se puede ver asi por que contine la pagina 3 tablas.

# %%
# Inspensionar datos
type(datos_html)
# Out:
# list

# %%
# Tamaño
len(datos_html)
# Out:
# 3

# %% [markdown]
# Extraemos la tabla deseada

# %%
# Extración de tablas
top_peliculas = datos_html[1]
top_peliculas.head()
# Out:
#                  Film  Release year              Director  \
# 0        Citizen Kane          1941          Orson Welles
# 1          Casablanca          1942        Michael Curtiz
# 2       The Godfather          1972  Francis Ford Coppola
# 3  Gone with the Wind          1939        Victor Fleming
# 4  Lawrence of Arabia          1962            David Lean
#
#                      Production companies  Rank
# 0                      RKO Radio Pictures     1
# 1                   Warner Bros. Pictures     2
# 2  Paramount Pictures, Alfran Productions     3
# 3         Selznick International Pictures     4
# 4                        Horizon Pictures     5

# %% [markdown]
# ### Exportación de HTML
#
# Mediante la **exportación de datos** con la función
#
# ```
# .to_html()
# ```
# Documentación: [pandas.to_html( )](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_html.html#pandas.DataFrame.to_html)

# %%
# Exportacion en html
top_peliculas.to_html('top_peliculas.html',index=False)

# %%
top_peliculas.to_csv('top_peliculas_1998.csv',index=False)

# %% [markdown]
# ### Importación de HTML e XLM
#
# Mediante la **lectura de datos** con la función
#
# ```
# .read_xml()
# ```
# Documentación: [read_xml( )](https://pandas.pydata.org/docs/reference/api/pandas.read_xml.html#pandas.read_xml)

# %%
# Importación de archivo xml
datos_xml = pd.read_xml('/content/imdb_top_1000.xml')
datos_xml.head()
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3      3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4      4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# ...

# %% [markdown]
# ### Exportación de XML
# Mediante la **exportación de datos** con la función
#
# ```
# .to_xml()
# ```
# Documentación: [pandas.to_xml( )](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_xml.html#pandas.DataFrame.to_xml)

# %%
# Exportación en xml
datos_xml.to_xml('datos_xml.xml', index=False)

# %%
# Lectura a partir de un url.
url_html = 'https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n'
pd.read_html(url_html)[0]
# Out:
#      N.º                   País (o territorio dependiente)  \
# 0      1                                             India
# 1      2                                        China[12]​
# 2      3                                    Estados Unidos
# 3      4                                         Indonesia
# 4      5                                          Pakistán
# ..   ...                                               ...
# 241  242                           Islas Cocos (Australia)
# 242  243  Islas Ultramarinas Menores de los Estados Unidos
# 243  244                               Islas Pitcairn (RU)
# 244  NaN                                             Mundo
# 245   N°                   País (o territorio dependiente)
#
#     Proyección exponencial de la población al 1/7/2025[7]​  \
# 0                                        1 417 492 000
# 1                                        1 407 934 000
# 2                                          342 181 000
# ...

# %% [markdown]
# ## Archivos SQL

# %% [markdown]
# ### Importación de base de datos SQL
#
# Mediante la **lectura de datos** con la función
#
# ```
# .read_sql()
# ```
# Documentación: [read_sql()](https://pandas.pydata.org/docs/reference/api/pandas.read_sql.html#pandas.read_sql)
# y requerimos de la paqueterias siguientes:

# %%
import sqlalchemy
# Crear motor base datos, visionario de tablas, cosulta tablas, inspeccionar, convertir texto
from sqlalchemy import create_engine, MetaData, Table, inspect, text, select

# %%
# Crear mi base de datos de sqlite en memoria local (tipo, donde)
engine = create_engine('sqlite:///:memory:')

# %%
archivo_sql = '/content/clientes_banco.csv'

# %%
datos_sql = pd.read_csv(archivo_sql)

# %%
datos_sql.head()
# Out:
#    ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0     5008804    32    Nivel superior  Relación-estable             2.0
# 1     5008805    32    Nivel superior  Relación-estable             2.0
# 2     5008806    58  Nivel intermedio            Casado             2.0
# 3     5008808    52  Nivel intermedio           Soltero             1.0
# 4     5008809    52  Nivel intermedio           Soltero             1.0
#
#   Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0           Empleado       Otro           12.0           427500.0
# 1           Empleado       Otro           12.0           427500.0
# 2           Empleado  Seguridad            3.0           112500.0
# 3   Business Partner     Ventas            8.0           270000.0
# 4   Business Partner     Ventas            8.0           270000.0
#
#    Tiene_carro                  Vivienda
# 0          1.0    Departamento alquilado
# 1          1.0    Departamento alquilado
# ...

# %% [markdown]
# ### Exportación de base de datos SQL
# Mediante la **exportación de datos** con la función
#
# ```
# .to_sql()
# ```
# Documentación: [pandas.to_sql( )](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_sql.html#pandas.DataFrame.to_sql)

# %%
datos_sql.to_sql('clientes', con=engine, index=False)
# Out:
# 340581

# %%
inspector = inspect(engine)

# %%
# Que tablas leyo
print(inspector.get_table_names())
# Out:
# ['clientes']

# %% [markdown]
# ### Consultas sql

# %%
# Consulta
query = 'SELECT * FROM clientes WHERE Categoria_de_renta = "Empleado"'

# %%
# Leer consultas
empleados=pd.read_sql(sql=text(query), con=engine.connect())
empleados.head()
# Out:
#    ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0     5008804    32    Nivel superior  Relación-estable             2.0
# 1     5008805    32    Nivel superior  Relación-estable             2.0
# 2     5008806    58  Nivel intermedio            Casado             2.0
# 3     5008815    46    Nivel superior            Casado             2.0
# 4     5112956    46    Nivel superior            Casado             2.0
#
#   Categoria_de_renta     Ocupacion  Años_empleado  Rendimiento_anual  \
# 0           Empleado          Otro           12.0           427500.0
# 1           Empleado          Otro           12.0           427500.0
# 2           Empleado     Seguridad            3.0           112500.0
# 3           Empleado  Contabilidad            2.0           270000.0
# 4           Empleado  Contabilidad            2.0           270000.0
#
#    Tiene_carro                  Vivienda
# 0          1.0    Departamento alquilado
# ...

# %%
empleados.to_sql('empleados', con=engine.connect(), index=False)
# Out:
# 175496

# %%
pd.read_sql_table('empleados', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable             2.0
# 1          5008805    32    Nivel superior  Relación-estable             2.0
# 2          5008806    58  Nivel intermedio            Casado             2.0
# 3          5008815    46    Nivel superior            Casado             2.0
# 4          5112956    46    Nivel superior            Casado             2.0
# ...            ...   ...               ...               ...             ...
# 175491     6397584    32  Nivel intermedio            Casado             3.0
# 175492     6397587    42  Nivel intermedio            Casado             2.0
# 175493     6397588    42  Nivel intermedio            Casado             2.0
# 175494     6397589    42  Nivel intermedio            Casado             2.0
# 175495     6397590    42  Nivel intermedio            Casado             2.0
#
# ...

# %%
pd.read_sql_table('empleados', con=engine.connect(), columns=['ID_Cliente','Edad'])
# Out:
#         ID_Cliente  Edad
# 0          5008804    32
# 1          5008805    32
# 2          5008806    58
# 3          5008815    46
# 4          5112956    46
# ...            ...   ...
# 175491     6397584    32
# 175492     6397587    42
# 175493     6397588    42
# 175494     6397589    42
# 175495     6397590    42
#
# [175496 rows x 2 columns]

# %%
query ='SELECT * FROM clientes'

# %%
pd.read_sql(sql=text(query), con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable             2.0
# 1          5008805    32    Nivel superior  Relación-estable             2.0
# 2          5008806    58  Nivel intermedio            Casado             2.0
# 3          5008808    52  Nivel intermedio           Soltero             1.0
# 4          5008809    52  Nivel intermedio           Soltero             1.0
# ...            ...   ...               ...               ...             ...
# 340576     6397587    42  Nivel intermedio            Casado             2.0
# 340577     6397588    42  Nivel intermedio            Casado             2.0
# 340578     6397589    42  Nivel intermedio            Casado             2.0
# 340579     6397590    42  Nivel intermedio            Casado             2.0
# 340580     6397591    42  Nivel intermedio              Casa             NaN
#
# ...

# %%
# Borrar registros
from sqlalchemy.exc import SQLAlchemyError #Iformacion de sql error
query = 'DELETE FROM clientes WHERE ID_Cliente = "5008804"'
try:
    r_set=engine.connect().execute(text(query))
except SQLAlchemyError as e:
    error = str(e.__dict__['orig'])
    print(error)
else:
  print('#Registros borrados:',r_set.rowcount)
# Out:
# #Registros borrados: 1

# %%
pd.read_sql_table('clientes', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable             2.0
# 1          5008806    58  Nivel intermedio            Casado             2.0
# 2          5008808    52  Nivel intermedio           Soltero             1.0
# 3          5008809    52  Nivel intermedio           Soltero             1.0
# 4          5008810    52  Nivel intermedio           Soltero             1.0
# ...            ...   ...               ...               ...             ...
# 340575     6397587    42  Nivel intermedio            Casado             2.0
# 340576     6397588    42  Nivel intermedio            Casado             2.0
# 340577     6397589    42  Nivel intermedio            Casado             2.0
# 340578     6397590    42  Nivel intermedio            Casado             2.0
# 340579     6397591    42  Nivel intermedio              Casa             NaN
#
# ...

# %%
# Actualizar registros
query = 'UPDATE clientes SET Grado_estudio="Nivel superior" WHERE ID_Cliente = "5008808"'
try:
    r_set=engine.connect().execute(text(query))
except SQLAlchemyError as e:
    error = str(e.__dict__['orig'])
    print(error)
else:
  print('#Registros actualizados:',r_set.rowcount)
# Out:
# #Registros actualizados: 1

# %%
pd.read_sql_table('clientes', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable             2.0
# 1          5008806    58  Nivel intermedio            Casado             2.0
# 2          5008808    52    Nivel superior           Soltero             1.0
# 3          5008809    52  Nivel intermedio           Soltero             1.0
# 4          5008810    52  Nivel intermedio           Soltero             1.0
# ...            ...   ...               ...               ...             ...
# 340575     6397587    42  Nivel intermedio            Casado             2.0
# 340576     6397588    42  Nivel intermedio            Casado             2.0
# 340577     6397589    42  Nivel intermedio            Casado             2.0
# 340578     6397590    42  Nivel intermedio            Casado             2.0
# 340579     6397591    42  Nivel intermedio              Casa             NaN
#
# ...

# %%
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['clientes', 'empleados']

# %%
# Actualizacion el registro del cliente ID 6397587
query = 'UPDATE clientes SET Rendimiento_anual="300000" WHERE ID_Cliente = "6397587"'
try:
    r_set=engine.connect().execute(text(query))
except SQLAlchemyError as e:
    error = str(e.__dict__['orig'])
    print(error)
else:
  print('#Registros actualizados:',r_set.rowcount)
# Out:
# #Registros actualizados: 1

# %%
# Eliminar el registro de cliente ID 5008809
query = 'DELETE FROM clientes WHERE ID_Cliente = "5008809"'
try:
    r_set=engine.connect().execute(text(query))
except SQLAlchemyError as e:
    error = str(e.__dict__['orig'])
    print(error)
else:
  print('#Registros borrados:',r_set.rowcount)
# Out:
# #Registros borrados: 1

# %% [markdown]
# Crear un nuevo registro de cliente siguiendo las especificaciones a continuación:
# - ID_cliente: 6850985
# - Edad: 33
# - Grado_estudio: Doctorado
# - Estado_civil: Soltero
# - Tamaño_familia: 1
# - Categoria_de_renta: Empleado
# - Ocupacion: TI
# - Años_empleado: 2
# - Rendimiento_anual: 290000
# - Tiene_carro: 0
# - Vivienda: Casa/Departamento propio

# %%
# Eliminar el registro de cliente ID 6850985
query = 'INSERT INTO clientes (ID_Cliente, Edad, Grado_estudio, Estado_civil, ' \
        'Tamaño_familia, Categoria_de_renta, Ocupacion, Años_empleado, ' \
        'Rendimiento_anual, Tiene_carro, Vivienda) ' \
        'VALUES (6850985, 33, "Doctorado", "Soltero", 1, "Empleado", "TI", ' \
        '2, 290000, 0, "Casa/Departamento propio")'
try:
    r_set=engine.connect().execute(text(query))
except SQLAlchemyError as e:
    error = str(e.__dict__['orig'])
    print(error)
else:
  print('#Registros nuevos:',r_set.rowcount)
# Out:
# #Registros nuevos: 1

# %%
pd.read_sql_table('clientes', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable             2.0
# 1          5008806    58  Nivel intermedio            Casado             2.0
# 2          5008808    52    Nivel superior           Soltero             1.0
# 3          5008810    52  Nivel intermedio           Soltero             1.0
# 4          5008811    52  Nivel intermedio           Soltero             1.0
# ...            ...   ...               ...               ...             ...
# 340575     6397588    42  Nivel intermedio            Casado             2.0
# 340576     6397589    42  Nivel intermedio            Casado             2.0
# 340577     6397590    42  Nivel intermedio            Casado             2.0
# 340578     6397591    42  Nivel intermedio              Casa             NaN
# 340579     6850985    33         Doctorado           Soltero             1.0
#
# ...
