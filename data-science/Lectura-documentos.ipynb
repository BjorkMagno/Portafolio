# %% [markdown]
# <a href="https://colab.research.google.com/github/BjorkMagno/Portafolio/blob/main/data-science/Lectura-documentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Super Store**

# %%
import pandas as pd

# %% [markdown]
# ## **Archivos CSV**

# %% [markdown]
# ### Importando archivos CSV
#
# Mediante la **lectura de datos** con la función
#
# ```
# .read()
# ```
# Documentación: [pandas.read( )](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)

# %%
# Almacenaciento de la lectura de CSV, con separación de comun
datos_normal = pd.read_csv('/content/superstore_data.csv')
datos_normal.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
# ALmacenamiento de lectura de un archivo cvs con ; de semparación.
datos_separador = pd.read_csv('/content/superstore_data_punto_coma.csv', sep=';')
datos_separador.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
# Lectura de las primeras filas.
datos_nrow = pd.read_csv('/content/superstore_data.csv', nrows=6)
datos_nrow
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
# 5   7348        1958         PhD         Single   71691        0         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
# ...

# %%
# Lectura de columnas especificas.
datos_usecols = pd.read_csv('/content/superstore_data.csv', usecols=['Id','Year_Birth','Income'])
datos_usecols
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
# Lectura de columnas por número.
datos_usecols_index = pd.read_csv('/content/superstore_data.csv', usecols=[0,1,4])
datos_usecols_index
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ### Exportación de CSV a CSV
#
# Mediante la **exportacion de datos** con la función
#
# ```
# .to_csv()
# ```
#
# Documentación: [pandas.to_csv( )](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html#pandas.DataFrame.to_csv)

# %%
# Importación con index.
datos_normal.to_csv('datos_normal.csv')

# %%
# Importación con index sin index anterior.
datos_normal.to_csv('datos_normal_sin_index.csv', index=False)

# %% [markdown]
# ### *Importación de csv online.*

# %% [markdown]
# 1. Asegúrese de que el archivo CSV esté separado por una coma o punto y coma.
# La codificación del archivo es ISO-8859-1.
# 1. Las primeras tres líneas del archivo se pueden ignorar, ya que el encabezado sólo comienza en la cuarta línea.
# 1. Las últimas 9 líneas también se pueden ignorar, ya que son sólo información sobre dónde se tomaron los datos.
# 1. Para eliminar las últimas líneas es necesario agregar el parámetro `engine='python'`.

# %%
# Almacenamiento de dirección.
url_csv ='/content/datos_sus.csv'

# %% [markdown]
# Luego podemos leer la url con la función read_csv y agregar los parámetros:
#
# - `encoding='ISO-8859-1'`: tipo de codificación de caracteres del archivo. En este caso, es la codificación ISO-8859-1 la que es común en los archivos en idioma portugués.
# - `sep=';'`: separador de los valores del archivo. En este caso, es el punto y coma (;).
# - `skiprows=3`: indica que las primeras tres líneas del archivo deben ignorarse ya que no contienen datos relevantes.
# - `skipfooter=9`: Indica que las últimas nueve líneas del archivo deben ignorarse ya que no contienen datos relevantes.
# -` engine='python'`: el motor utilizado para leer el archivo es Python. Esto es necesario cuando se utiliza el parámetro skipfooter, ya que el motor predeterminado no admite esta opción.

# %%
# ALmacenamienrtos de datos.
datos_url = pd.read_csv(url_csv, encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter = 9, engine='python')
datos_url.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0             Rondônia   1388528,39   2931283,42   1541682,52   1525314,96
# 1                 Acre    902416,00   1497206,26   1794028,48   1730469,42
# 2             Amazonas   4735529,42   7118990,57   8196635,49   8259378,42
# 3              Roraima    657889,53    777939,31    718688,03    839994,39
# 4                 Pará  18864744,11  19553758,20  21937342,70  20842829,69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953,84   1406150,68   3065279,01   3231494,61   3117178,63  ...
# 1   1819443,92   1828496,00   2511754,59   2089107,14   2275708,53  ...
# 2   7831399,90   8477273,62   9368858,72   9352532,70   9363099,35  ...
# 3    862347,96    832440,66    996693,09    894271,18    910424,17  ...
# 4  23249952,88  23240687,56  24002223,56  23341218,03  25172261,32  ...
#
#       2020/Jul     2020/Ago     2020/Set     2020/Out     2020/Nov  \
# ...

# %% [markdown]
# ## **Archivos EXCEL**

# %% [markdown]
# ### Importación de arcivos EXCEL
#
# Mediante la **lectura de datos** con la función
#
# ```
# .read_excel()
# ```
# Documentación: [read_excel()](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html#pandas.read_excel)

# %%
# Declaración de la variable archivo.
archivo = '/content/emisiones_CO2.xlsx'

# %%
# Almacenamiento y lectura del archivo.
datos_xlsx = pd.read_excel(archivo)
datos_xlsx.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    0.0     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    0.0     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    0.0     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    0.0     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    0.0     NaN     NaN  NaN      NaN
#
#    Quema  Otros  Per Capita
# 0    NaN    NaN         NaN
# 1    NaN    NaN         NaN
# 2    NaN    NaN         NaN
# 3    NaN    NaN         NaN
# 4    NaN    NaN         NaN

# %%
# Lista con todas las hojas del EXCEL
pd.ExcelFile(archivo).sheet_names
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %% [markdown]
# Para ver los primeros n datos.
# ```
# head(n)
# ```
# Para ver los ultimos n datos.
# ```
# tail(n)
# ```
# Para ver n datos aleatorios.
# ```
# sample(n)
# ```
# En caso de no poner nada se muestran 5.

# %%
# Almacenamiento de una hoja del excel por defecto es la primera.
datos_emisiones_percapita = pd.read_excel(archivo, sheet_name='fuentes')
datos_emisiones_percapita.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    NaN     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    NaN     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    NaN     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    NaN     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    NaN     NaN     NaN  NaN      NaN
#
#    Quema  Otros
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN

# %%
# Almacenamiento de la lectura de datos de A:D
datos_intervalo = pd.read_excel(archivo, sheet_name='emisiones_C02' , usecols='A:D')
datos_intervalo.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750    0.0
# 1  Afganistán                AFG  1751    0.0
# 2  Afganistán                AFG  1752    0.0
# 3  Afganistán                AFG  1753    0.0
# 4  Afganistán                AFG  1754    0.0

# %%
# Almacenamiento de la lectura de datos de A:D y 10 filas
datos_intervalo_nrows = pd.read_excel(archivo, sheet_name='emisiones_C02' , usecols='A:D', nrows=10)
datos_intervalo_nrows
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %% [markdown]
# ### Exportación de las tablas a EXCEL.
#
# Mediante la **exportación de datos** con la función
#
# ```
# .to_excel()
# ```
# Documentación: [pandas.to_excel( )](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_excel.html#pandas.DataFrame.to_excel)

# %%
datos_intervalo.to_excel("datos_intervalo.xlsx", index=False)

# %% [markdown]
# ### Importacion de Google sheets
#
# [https://docs.google.com/spreadsheets/d/1HjqlNjLsCZVnRlGhYdLCbZnorIhIl84a_0cMJAXWZDA/edit?usp=sharing](https://docs.google.com/spreadsheets/d/1HjqlNjLsCZVnRlGhYdLCbZnorIhIl84a_0cMJAXWZDA/edit?usp=sharing)

# %%
sheet_id = '1HjqlNjLsCZVnRlGhYdLCbZnorIhIl84a_0cMJAXWZDA'
sheet_name = 'emisiones_C02'
url_xlsx = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
datos_online = pd.read_csv(url_xlsx)
datos_online.head()
# Out:
#          País ISO 3166-1 alpha-3   Año Total Carbón Aceite  Gas Cemento Quema  \
# 0  Afganistán                AFG  1750     0    NaN    NaN  NaN     NaN   NaN
# 1  Afganistán                AFG  1751     0    NaN    NaN  NaN     NaN   NaN
# 2  Afganistán                AFG  1752     0    NaN    NaN  NaN     NaN   NaN
# 3  Afganistán                AFG  1753     0    NaN    NaN  NaN     NaN   NaN
# 4  Afganistán                AFG  1754     0    NaN    NaN  NaN     NaN   NaN
#
#   Otros Per Capita
# 0   NaN        NaN
# 1   NaN        NaN
# 2   NaN        NaN
# 3   NaN        NaN
# 4   NaN        NaN

# %% [markdown]
# ### Importacion Ejercicio.

# %% [markdown]
# Tenemos un [link de Google Sheets](https://cdn3.gnarususercontent.com.br/1980-pandas-e-s/emisiones_carbono_mundo.xlsx) que contiene datos importantes sobre las emisiones de dióxido de carbono en todo el mundo. El conjunto de datos se obtuvo de [Kaggle](https://www.kaggle.com/datasets/koustavghosh149/co2-emission-around-the-world) y consta de las emisiones de CO2 per cápita de todos los países del mundo entre 1990 y 2019.
#
# En este desafío, tu función es leer este link de Google Sheets y luego guardar el DataFrame obtenido en formato CSV.

# %% [markdown]
# ## Archivos JSON

# %% [markdown]
# ### Importación de JSON

# %% [markdown]
# ### Exportación JSON

# %% [markdown]
# ## Archivos HTML e XLM

# %% [markdown]
# ### Importación de HTML e XLM

# %% [markdown]
# ### Exportación de HTML e XLM

# %% [markdown]
# ## Archivos SQL

# %% [markdown]
# ### Importación de base de datos SQL

# %% [markdown]
# ### Exportación de base de datos SQL
