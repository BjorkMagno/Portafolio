# %% [markdown]
# <a href="https://colab.research.google.com/github/BjorkMagno/Portafolio/blob/main/data-science/desafios/alumnos/alumnos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Análisis de alumnos.**
# Realizaremos algunos análisis utilizando un archivo CSV: [alumnos.csv](https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv)

# %% [markdown]
# ## Importación de las paqueterías.

# %%
import pandas as pd

# %% [markdown]
# ## Importación y almacenación de datos.

# %%
alumnos_url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'
alumnos = pd.read_csv(alumnos_url)

# %% [markdown]
# ## Visualización del DataFrame.

# %%
# Visualización de las primeras 7 filas del DataFrame.
alumnos.head(7)
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True
# 5    Bruna    23   NaN    False
# 6  Daniela    21   7.0     True

# %%
# Visualización de las ultimas 5 filas del DataFrame.
alumnos.tail()
# Out:
#     Nombre  Edad  Nota   Aprobado
# 13  Miriam    25   9.0       True
# 14   Pablo    37   NaN      False
# 15  Milena    29   7.0       True
# 16   Lucas    33   NaN      False
# 17   Nadia    34   8.0  Verdadero

# %%
# Visualización de los daatos de las columnas 'Edad' y 'Nota'
alumnos[['Edad', 'Nota']]
# Out:
#     Edad  Nota
# 0     20   7.5
# 1     18   NaN
# 2     27   2.5
# 3     18   5.0
# 4     21  10.0
# 5     23   NaN
# 6     21   7.0
# 7     19   6.0
# 8     35   5.6
# 9     28   NaN
# 10    21   NaN
# 11    24   4.5
# 12    26  10.0
# 13    25   9.0
# 14    37   NaN
# 15    29   7.0
# 16    33   NaN
# 17    34   8.0

# %% [markdown]
# ## Exploración del DataFrame.

# %%
# Verificación de la cantidad de filas y columnas.
alumnos.shape
# Out:
# (18, 4)

# %%
print(f'El DataFrame contiene {alumnos.shape[0]} filas y {alumnos.shape[1]} columnas.')
# Out:
# El DataFrame contiene 18 filas y 4 columnas.

# %%
# Observación de las columnas.
alumnos.columns
# Out:
# Index(['Nombre', 'Edad', 'Nota', 'Aprobado'], dtype='object')

# %%
# Tipos de datos de las columnas.
alumnos.dtypes
# Out:
# Nombre       object
# Edad          int64
# Nota        float64
# Aprobado     object
# dtype: object

# %%
alumnos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    18 non-null     object
#  1   Edad      18 non-null     int64
#  2   Nota      12 non-null     float64
#  3   Aprobado  18 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 708.0+ bytes

# %% [markdown]
# ## Calculos

# %%
#Calcular algunas estadísticas descritivas básicas.
alumnos.describe()
# Out:
#             Edad       Nota
# count  18.000000  12.000000
# mean   25.500000   6.841667
# std     6.070662   2.264532
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# ## Tratamiento de datos nulos.

# %%
alumnos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
# Tratamiento de nota
alumnos_notas = alumnos.fillna(0)
alumnos_notas
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
index_alumnos_eliminados = alumnos_notas.query('Nombre == "Alicia" | Nombre == "Carlos"').index
alumnos_notas.drop(index_alumnos_eliminados,axis=0, inplace=True)
alumnos_notas
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
# Filtro de alumnos aprobados
fitro_aprobatorio = (alumnos_notas['Aprobado'] == 'True')
alumnos_aprobados = alumnos_notas[fitro_aprobatorio]

# %%
# Remplación de notas
alumnos_aprobados = alumnos_aprobados.replace(7.0, 8.0)

# %%
alumnos_aprobados.to_csv('alumnos_aprobados.csv', index=False)

# %% [markdown]
# ##Demandas DEV

# %% [markdown]
# ### Los estudiantes participaron en una actividad extracurricular y ganaron puntos extras. Estos puntos extras corresponden al 40% de su nota actual. Por lo tanto, crea una columna llamada "Puntos_extras" que contenga los puntos extras de cada estudiante, es decir, el 40% de su nota actual.

# %%
alumnos_dev = alumnos_notas.copy()
alumnos_dev['Puntos_extras'] = alumnos_dev['Nota'] * 0.4
alumnos_dev
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras
# 0    Alberto    20   7.5       True            3.0
# 1        Ana    18   0.0      False            0.0
# 2     Camila    27   2.5      False            1.0
# 3      David    18   5.0      False            2.0
# 4      Brian    21  10.0       True            4.0
# 5      Bruna    23   0.0      False            0.0
# 6    Daniela    21   7.0       True            2.8
# 9     Victor    28   0.0      False            0.0
# 10    Danilo    21   0.0      False            0.0
# 11   Ignacio    24   4.5      False            1.8
# 12  Stephany    26  10.0       True            4.0
# 13    Miriam    25   9.0       True            3.6
# 14     Pablo    37   0.0      False            0.0
# 15    Milena    29   7.0       True            2.8
# 16     Lucas    33   0.0      False            0.0
# 17     Nadia    34   8.0  Verdadero            3.2

# %%
alumnos_dev['Notas_finales'] = alumnos_dev['Nota'] + alumnos_dev['Puntos_extras']
alumnos_dev
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras  Notas_finales
# 0    Alberto    20   7.5       True            3.0           10.5
# 1        Ana    18   0.0      False            0.0            0.0
# 2     Camila    27   2.5      False            1.0            3.5
# 3      David    18   5.0      False            2.0            7.0
# 4      Brian    21  10.0       True            4.0           14.0
# 5      Bruna    23   0.0      False            0.0            0.0
# 6    Daniela    21   7.0       True            2.8            9.8
# 9     Victor    28   0.0      False            0.0            0.0
# 10    Danilo    21   0.0      False            0.0            0.0
# 11   Ignacio    24   4.5      False            1.8            6.3
# 12  Stephany    26  10.0       True            4.0           14.0
# 13    Miriam    25   9.0       True            3.6           12.6
# 14     Pablo    37   0.0      False            0.0            0.0
# ...

# %% [markdown]
# Dado que hubo una puntuación extra, algunos estudiantes que no habían sido aprobados antes pueden haber sido aprobados ahora. En función de esto, crea una columna llamada "Aprobado_final" con los siguientes valores:
#
# True: si el estudiante está aprobado (la nota final debe ser mayor o igual a 7.0).
# False: si el estudiante está reprobado (la nota final debe ser menor que 7.0)

# %%
alumnos_dev['Aprobado'] = alumnos_dev['Nota'].apply(lambda x: 'True' if x >= 7 else 'False')
alumnos_dev['Aprobado_final'] = alumnos_dev['Notas_finales'].apply(lambda x: 'True' if x >= 7 else 'False')
alumnos_dev
# Out:
#       Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales Aprobado_final
# 0    Alberto    20   7.5     True            3.0           10.5           True
# 1        Ana    18   0.0    False            0.0            0.0          False
# 2     Camila    27   2.5    False            1.0            3.5          False
# 3      David    18   5.0    False            2.0            7.0           True
# 4      Brian    21  10.0     True            4.0           14.0           True
# 5      Bruna    23   0.0    False            0.0            0.0          False
# 6    Daniela    21   7.0     True            2.8            9.8           True
# 9     Victor    28   0.0    False            0.0            0.0          False
# 10    Danilo    21   0.0    False            0.0            0.0          False
# 11   Ignacio    24   4.5    False            1.8            6.3          False
# 12  Stephany    26  10.0     True            4.0           14.0           True
# ...

# %% [markdown]
# Realiza una selección y verifica qué estudiantes no habían sido aprobados anteriormente, pero ahora fueron aprobados después de sumar los puntos extras.

# %%
alumnos_dev.query('Aprobado == "False" & Aprobado_final == "True"')
# Out:
#   Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales Aprobado_final
# 3  David    18   5.0    False            2.0            7.0           True
